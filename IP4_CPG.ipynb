# %% [markdown]
# # IP4_CPG by Connor Goodman

# %% [markdown]
# ### Importing needed tools

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %% [markdown]
# ### Importing data set for analysis

# %%
df=pd.read_csv("LoL 2021 Worlds.csv")

# %% [markdown]
# ### Seeing Size and Shape of Dataset

# %%
len(df)
# Out:
# 220

# %%
df.shape
# Out:
# (220, 20)

# %% [markdown]
# ### Checking data and information within the dataset

# %%
df.info()
# bulk of info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Team                   220 non-null    object
#  1   Player                 220 non-null    object
#  2   Opponent               220 non-null    object
#  3   Position               220 non-null    object
#  4   Champion               220 non-null    object
#  5   Kills                  220 non-null    int64
#  6   Deaths                 220 non-null    int64
#  7   Assists                220 non-null    int64
#  8   Creep Score            220 non-null    int64
#  9   Gold Earned            220 non-null    int64
#  10  Champion Damage Share  220 non-null    float64
#  11  Kill Participation     220 non-null    float64
#  12  Wards Placed           220 non-null    int64
#  13  Wards Destroyed        220 non-null    int64
# ...

# %%
df.head(10)
#first 10 rows of info
# Out:
#   Team     Player Opponent Position      Champion  Kills  Deaths  Assists  \
# 0  UOL       Boss       GS      Top       Camille      4       5        3
# 1   GS      Crazy      UOL      Top          Gwen      3       1        9
# 2  UOL   Ahahacik       GS   Jungle       Trundle      2       4        5
# 3   GS     Mojito      UOL   Jungle         Talon      5       4       10
# 4  UOL     Nomanz       GS      Mid       Leblanc      1       3        4
# 5   GS     Bolulu      UOL      Mid  Twisted Fate      5       0       13
# 6  UOL   Argonavt       GS      Adc        Ezreal      1       5        3
# 7   GS      Alive      UOL      Adc  Miss Fortune      9       2        5
# 8  UOL     Santas       GS  Support         Amumu      1       6        4
# 9   GS  Zergsting      UOL  Support         Rakan      0       2       16
#
#    Creep Score  Gold Earned  Champion Damage Share  Kill Participation  \
# 0          188        11107                   0.17                0.78
# ...

# %%
df1=df.sample(10)
#random 10 rows of info
#assigning df1 to a sample also allows me to use df1 in a plot to show a less amount of data but averaging the same
df1
# Out:
#     Team      Player Opponent Position      Champion  Kills  Deaths  Assists  \
# 126  RED       Titan      HLE      Adc  Miss Fortune      2       3        6
# 28    GS   Zergsting      BYG  Support          Bard      1       0       10
# 167  UOL    Argonavt       C9      Adc         Senna      2       0       16
# 114  BYG       Maoan       C9      Mid          Yone      2       5        8
# 22    GS      Mojito      BYG   Jungle        Qiyana      5       2        9
# 48   HLE        Vsta      INF  Support         Leona      1       1        5
# 50   LNG         Ale      PCE      Top         Fiora      8       1        2
# 0    UOL        Boss       GS      Top       Camille      4       5        3
# 136  INF  Whitelotus      PCE      Adc      Aphelios      2       3        7
# 63   RED       Aegis      INF   Jungle        Lillia      0       1        7
#
#      Creep Score  Gold Earned  Champion Damage Share  Kill Participation  \
# ...

# %%
df2=df.sample(25)
#random 25 rows of info
#assigning df2 to a sample also allows me to use df2 in a plot to show less amount of total data but more than just 10 rows in df1
df2
# Out:
#     Team      Player Opponent Position      Champion  Kills  Deaths  Assists  \
# 170  DFM         Evi      BYG      Top         Urgot     10       0        6
# 82    C9      Blaber       GS   Jungle       Taliyah      7       2       10
# 122  RED       Aegis      HLE   Jungle      Xin Zhao      1       5        4
# 93   UOL    Ahahacik      BYG   Jungle       Lee Sin      0       4        3
# 110  BYG       Liang       C9      Top        Lillia      3       4        6
# 98   BYG        Kino      UOL  Support         Rakan      0       2       14
# 155  HLE       Chovy      PCE      Mid          Azir      3       0        4
# 164   C9       Perkz      UOL      Mid       Leblanc      3       4        4
# 201   C9       Fudge      DFM      Top         Jayce      2       3        8
# 178  DFM       Gaeng      BYG  Support         Leona      0       2       15
# 44   HLE       Chovy      INF      Mid          Azir      1       2        1
# ...

# %%
df.tail()
#final rows of info
# Out:
#     Team    Player Opponent Position Champion  Kills  Deaths  Assists  \
# 215  BYG     Maoan      UOL      Mid     Ryze      4       4        2
# 216  UOL  Argonavt      BYG      Adc    Senna      1       3        9
# 217  BYG     Doggo      UOL      Adc   Draven     10       2        4
# 218  UOL    Santas      BYG  Support   Wukong      0       4        7
# 219  BYG      Kino      UOL  Support    Rakan      0       5        9
#
#      Creep Score  Gold Earned  Champion Damage Share  Kill Participation  \
# 215          356        15558                   0.23                0.32
# 216           58         9554                   0.16                0.71
# 217          353        20546                   0.38                0.74
# 218          200        10354                   0.11                0.50
# 219           41         9304                   0.06                0.47
#
#      Wards Placed  Wards Destroyed  Ward Interactions  Dragons For  \
# ...

# %% [markdown]
# ### Using Charts and Plots we can acess the data within the dataset to clearly see what is going on

# %%
df.info()
#using info to have all column names and datatypes available to clearly add to plots
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Team                   220 non-null    object
#  1   Player                 220 non-null    object
#  2   Opponent               220 non-null    object
#  3   Position               220 non-null    object
#  4   Champion               220 non-null    object
#  5   Kills                  220 non-null    int64
#  6   Deaths                 220 non-null    int64
#  7   Assists                220 non-null    int64
#  8   Creep Score            220 non-null    int64
#  9   Gold Earned            220 non-null    int64
#  10  Champion Damage Share  220 non-null    float64
#  11  Kill Participation     220 non-null    float64
#  12  Wards Placed           220 non-null    int64
#  13  Wards Destroyed        220 non-null    int64
# ...

# %% [markdown]
# ## Matplotlib Charts

# %%
plt.figure(figsize=(15,20))
plt.bar(df2['Player'], df2['Kills'])
plt.xlabel("Player")
plt.ylabel("Kills")
plt.show()

# %%
plt.figure(figsize=(15,20))
plt.bar(df['Team'], df['Kills'])
plt.xlabel("Team")
plt.ylabel("Kills")
plt.show()

# %%
plt.scatter(df['Team'],df['Gold Earned'])
plt.show()

# %% [markdown]
# ## SeaBorn Chats

# %%
df.info()
#ease of access to info again
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Team                   220 non-null    object
#  1   Player                 220 non-null    object
#  2   Opponent               220 non-null    object
#  3   Position               220 non-null    object
#  4   Champion               220 non-null    object
#  5   Kills                  220 non-null    int64
#  6   Deaths                 220 non-null    int64
#  7   Assists                220 non-null    int64
#  8   Creep Score            220 non-null    int64
#  9   Gold Earned            220 non-null    int64
#  10  Champion Damage Share  220 non-null    float64
#  11  Kill Participation     220 non-null    float64
#  12  Wards Placed           220 non-null    int64
#  13  Wards Destroyed        220 non-null    int64
# ...

# %%
line_plot=sns.lineplot(x="Team",y='Creep Score',data=df,ci=None,color='red')
sns.set(rc={'figure.figsize':(21,21)})
#teams average creep score

# %%
bar_plot=sns.barplot(x='Player',y="Wards Placed",data=df2,ci=False)
#25 random players wards placed per games

# %%
histo_plot=df["Gold Earned"].values
sns.distplot(histo_plot,color='red')
#the gold income spikes over game time (x axis is game over time / average)
# Out:
# C:\Users\Connor\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
scatter_plot=sns.scatterplot(x="Kills",
                            y='Gold Earned',
                            data=df,
                            color='green')
#plots of data are plotted to show the teams gold earned amounts based on kills 
# example: 12 kill teams have a higher average gold earned than 2

# %%
pair_plot_small=sns.pairplot(df[['Team','Player','Kills','Gold Earned',"Wards Placed"]])

# %%
pair_plot=sns.pairplot(df)
